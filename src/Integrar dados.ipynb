# %%
import pandas as pd

pd.set_option('display.max_columns', None)
#pd.reset_option('display.max_rows')
pd.set_option('display.max_rows', 20)  # ao invés de none pode por INT do limite
pd.set_option('display.max_colwidth', 15)

# %%
df_soevals = pd.read_csv('../data/df_jogos.csv')[['id','Evals']] #aqui há dados errados (roque) porém tem a computação das evals, que demora 5 horas (a qual está correta)
df_evals = pd.read_csv('../data/df_evals.csv') #analise das evals
df_jogos = pd.read_csv('../data/df_jogos_semeval.csv') #os dados dos jogos corretos mas sem as evals
df_plays = pd.read_csv('../data/df_plays.csv')  #os dados das linhas jogadas

# %%
df_jogos.drop(columns=['White Short Castle', 'White Long Castle','Black Short Castle', 'Black Long Castle', 'Opposite side castling'], inplace=True)

# %%
df = df_jogos.merge(df_soevals, on='id').merge(df_evals, on='id').merge(df_plays, on='id')
df.to_csv('../data/df_completo.csv', index=False)

# %%
df
# Out:
#            id           Event          Site  Date           White  \
# 0           0        New York      New York  1918  Morrison, J...
# 1        1168        New York      New York  1918  Capablanca,...
# 2        1772            Brno          Brno  1921        Sery, S.
# 3        2129          NLD-ch      Nijmegen  1921  Te Kolste, ...
# 4        2522         USA sim           USA  1926  Lasker, Ema...
# ...       ...             ...           ...   ...             ...
# 2979  2113381  23rd Europe...  Terme Catez   2021        Agopov,M
# 2980  2117758  8th Sunway ...       Sitges   2021       Kurmann,O
# 2981  2118961  7th Gashimo...         Baku   2021  Karjakin,Se...
# 2982  2119588  World Rapid...       Warsaw   2021  Loskutova,V...
# 2983  2120268  World Rapid...       Warsaw   2021       Dvirnyy,D
#
#                Black   Result  BlackElo  ECO  WhiteElo  WhiteWon  BlackWon  \
# 0     Marshall, F...      0-1       NaN  C89       NaN         0         1
# ...

# %%
import pandas as pd

pd.set_option('display.max_columns', None)
#pd.reset_option('display.max_rows')
pd.set_option('display.max_rows', 20)  # ao invés de none pode por INT do limite
pd.set_option('display.max_colwidth', 15)

# %%
df = pd.read_csv('../data/df_jogos.csv')

# %%
df
# Out:
#            id           Event          Site  Date           White  \
# 0           0        New York      New York  1918  Morrison, J...
# 1        1168        New York      New York  1918  Capablanca,...
# 2        1772            Brno          Brno  1921        Sery, S.
# 3        2129          NLD-ch      Nijmegen  1921  Te Kolste, ...
# 4        2522         USA sim           USA  1926  Lasker, Ema...
# ...       ...             ...           ...   ...             ...
# 2979  2113381  23rd Europe...  Terme Catez   2021        Agopov,M
# 2980  2117758  8th Sunway ...       Sitges   2021       Kurmann,O
# 2981  2118961  7th Gashimo...         Baku   2021  Karjakin,Se...
# 2982  2119588  World Rapid...       Warsaw   2021  Loskutova,V...
# 2983  2120268  World Rapid...       Warsaw   2021       Dvirnyy,D
#
#                Black   Result  BlackElo  ECO  WhiteElo  White Short Castle  \
# 0     Marshall, F...      0-1       NaN  C89       NaN               1
# 1     Marshall, F...      1-0       NaN  C89       NaN               1
# 2     Vecsey, Zoltan      1-0       NaN  C89       NaN               1
# 3      Loman, Rudolf      0-1       NaN  C89       NaN               1
# 4     Bigelow, Ho...      0-1       NaN  C89       NaN               1
# ...              ...      ...       ...  ...       ...             ...
# 2979        Ragger,M  1/2-1/2    2668.0  C89    2430.0               1
# 2980   Van Dael,Siem      1-0    2300.0  C89    2466.0               1
# 2981       Caruana,F  1/2-1/2    2792.0  C89    2743.0               1
# 2982     Abdumalik,Z      1-0    2491.0  C89    2100.0               1
# 2983   Lopusiewicz,P  1/2-1/2    2301.0  C89    2492.0               1
#
#       White Long Castle  Black Short Castle  Black Long Castle  \
# 0                  0                  1                   0
# 1                  0                  1                   0
# 2                  0                  1                   0
# 3                  0                  1                   0
# 4                  0                  1                   0
# ...              ...                ...                 ...
# 2979               0                  1                   0
# 2980               0                  1                   0
# 2981               0                  1                   0
# 2982               0                  1                   0
# 2983               0                  1                   0
#
#       Opposite side castling           Evals  WhiteWon  BlackWon  Moves  \
# 0                  0          [38, 54, 25...         0         1     85
# 1                  0          [35, 43, 27...         1         0     36
# 2                  0          [30, 54, 55...         1         0     17
# 3                  0          [37, 48, 46...         0         1     19
# 4                  0          [26, 50, 52...         0         1     20
# ...              ...                     ...       ...       ...    ...
# 2979               0          [26, 28, 27...         0         0     55
# 2980               0          [25, 50, 41...         1         0     51
# 2981               0          [24, 37, 35...         0         0     37
# 2982               0          [34, 54, 45...         1         0     42
# 2983               0          [35, 50, 25...         0         0     88
#
#       WhiteFinalPiecesCount  BlackFinalPiecesCount  FinalPiecesCount  \
# 0                  1                      3                      4
# 1                  7                      5                     12
# 2                 12                     10                     22
# 3                 11                     10                     21
# 4                 11                     11                     22
# ...              ...                    ...                    ...
# 2979               2                      1                      3
# 2980               8                      5                     13
# 2981               4                      4                      8
# 2982               6                      5                     11
# 2983               0                      0                      0
#
#       QueenTrade
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0
# ...          ...
# 2979           1
# 2980           0
# 2981           1
# 2982           1
# 2983           1
#
# [2984 rows x 23 columns]

# %%
evals_list = df['Evals'][1]
evals_list = evals_list.strip('[]').split(",")
print(len(evals_list))
print(evals_list[-1])
evals_list
# Out:
# 71
#  99995
# ['35',
#  ' 43',
#  ' 27',
#  ' 39',
#  ' 34',
#  ' 33',
#  ' 50',
#  ' 50',
#  ' 54',
#  ' 51',
#  ' 43',
#  ' 59',
#  ' 56',
#  ' 55',
#  ' 60',
#  ' 44',
#  ' 32',
#  ' 43',
#  ' 102',
#  ' 68',
#  ' 36',
#  ' 78',
#  ' 52',
#  ' 102',
#  ' 47',
#  ' 154',
#  ' 154',
#  ' 145',
#  ' 84',
#  ' 118',
#  ' 119',
#  ' 184',
#  ' 180',
#  ' 223',
#  ' 184',
#  ' 193',
#  ' 190',
#  ' 224',
#  ' 223',
#  ' 202',
#  ' 199',
#  ' 199',
#  ' 60',
#  ' 251',
#  ' 232',
#  ' 259',
#  ' 210',
#  ' 234',
#  ' 262',
#  ' 281',
#  ' 306',
#  ' 381',
#  ' 418',
#  ' 349',
#  ' 377',
#  ' 500',
#  ' 550',
#  ' 551',
#  ' 559',
#  ' 547',
#  ' 483',
#  ' 450',
#  ' 417',
#  ' 549',
#  ' 563',
#  ' 627',
#  ' 677',
#  ' 717',
#  ' 812',
#  ' 99994',
#  ' 99995']

# %%
dados = []

for index, row in df.iterrows():
    linha = {}
    evals_list = row['Evals']
    evals_list = evals_list.strip('[]').split(",")

    linha['id'] = row['id']
    linha['MaxEval'] = max(evals_list)
    linha['MinEval'] = min(evals_list)
    linha['FinalEval'] = evals_list[-1]

    linha['W<=10'] = 0
    linha['W<=25'] = 0
    linha['W<=50'] = 0
    linha['W<=100'] = 0
    linha['W<=200'] = 0
    linha['W<=500'] = 0
    linha['W>500'] = 0
    linha['B<=10'] = 0
    linha['B<=25'] = 0
    linha['B<=50'] = 0
    linha['B<=100'] = 0
    linha['B<=200'] = 0
    linha['B<=500'] = 0
    linha['B>500'] = 0

    
    turn = False #true branca, false preta
    first = True #primeira jogada
    jogada_anterior = 0
    jogada_atual = 0
    direction = 0 #1 subindo, -1 descendo
    for eval in evals_list:
        turn = not turn
        jogada_atual = int(eval)

        #testa se é o primeiro lance
        if first:
            jogada_anterior = jogada_atual
            first = False
            continue

        #testa de quem é a jogada
        if turn: #branca
            var = abs(jogada_anterior - jogada_atual)
            #testa direção da variação
            if jogada_anterior >= jogada_atual:
                if var <= 10:
                    linha['W<=10'] += 1
                elif var <= 25:
                    linha['W<=25'] += 1
                elif var <= 50:
                    linha['W<=50'] += 1
                elif var <= 100:
                    linha['W<=100'] += 1
                elif var <= 200:
                    linha['W<=200'] += 1
                elif var <= 500:
                    linha['W<=500'] += 1
                else:
                    linha['W>500'] += 1
            else:
                if var <= 10:
                    linha['W<=10'] += 1
                
        else: #preta
            var = abs(jogada_anterior - jogada_atual)
            #testa direção da variação
            if jogada_anterior >= jogada_atual:
                linha['B<=10'] += 1
            else:
                if var <= 10:
                    linha['B<=10'] += 1
                elif var <= 25:
                    linha['B<=25'] += 1
                elif var <= 50:
                    linha['B<=50'] += 1
                elif var <= 100:
                    linha['B<=100'] += 1
                elif var <= 200:
                    linha['B<=200'] += 1
                elif var <= 500:
                    linha['B<=500'] += 1
                else:
                    linha['B>500'] += 1

        jogada_anterior = jogada_atual
    dados.append(linha)

df_evals = pd.DataFrame(dados)

# %%
df_evals
# Out:
#            id MaxEval MinEval FinalEval  W<=10  W<=25  W<=50  W<=100  W<=200  \
# 0           0      38     -10     -6153     21     13     13      13       9
# 1        1168      35     102     99995     13      3      5       3       1
# 2        1772      30     106     99999      9      2      2       0       0
# 3        2129      37    -916      -972      9      3      2       0       1
# 4        2522      26   -1187     -1187      9      2      2       0       0
# ...       ...     ...     ...       ...    ...    ...    ...     ...     ...
# 2979  2113381      26      -1       -49     17     15      7       4       1
# 2980  2117758      25       0     99999     19      8      5       5       3
# 2981  2118961      24      -1         0     16     12      2       0       1
# 2982  2119588      34      -8       778     19      8      4       2       0
# 2983  2120268      35    -112         0     52      9      7       4       4
#
#       W<=500  W>500  B<=10  B<=25  B<=50  B<=100  B<=200  B<=500  B>500
# 0          2      0     44     18     10       6       4       2      0
# 1          0      0     15      5      7       3       4       0      1
# 2          0      0      9      5      0       1       0       0      1
# 3          0      1      8      6      1       2       1       0      0
# 4          3      0     15      2      1       1       0       0      0
# ...      ...    ...    ...    ...    ...     ...     ...     ...    ...
# 2979       2      0     32      7      6       6       1       2      0
# 2980       1      0     22      7      9       5       3       2      2
# 2981       0      0     25      6      3       2       0       0      0
# 2982       0      0     20      8      5       6       1       1      0
# 2983       2      1     63     10      3       7       1       2      1
#
# [2984 rows x 18 columns]

# %%
df
# Out:
#            id           Event          Site  Date           White  \
# 0           0        New York      New York  1918  Morrison, J...
# 1        1168        New York      New York  1918  Capablanca,...
# 2        1772            Brno          Brno  1921        Sery, S.
# 3        2129          NLD-ch      Nijmegen  1921  Te Kolste, ...
# 4        2522         USA sim           USA  1926  Lasker, Ema...
# ...       ...             ...           ...   ...             ...
# 2979  2113381  23rd Europe...  Terme Catez   2021        Agopov,M
# 2980  2117758  8th Sunway ...       Sitges   2021       Kurmann,O
# 2981  2118961  7th Gashimo...         Baku   2021  Karjakin,Se...
# 2982  2119588  World Rapid...       Warsaw   2021  Loskutova,V...
# 2983  2120268  World Rapid...       Warsaw   2021       Dvirnyy,D
#
#                Black   Result  BlackElo  ECO  WhiteElo  White Short Castle  \
# 0     Marshall, F...      0-1       NaN  C89       NaN               1
# 1     Marshall, F...      1-0       NaN  C89       NaN               1
# 2     Vecsey, Zoltan      1-0       NaN  C89       NaN               1
# 3      Loman, Rudolf      0-1       NaN  C89       NaN               1
# 4     Bigelow, Ho...      0-1       NaN  C89       NaN               1
# ...              ...      ...       ...  ...       ...             ...
# 2979        Ragger,M  1/2-1/2    2668.0  C89    2430.0               1
# 2980   Van Dael,Siem      1-0    2300.0  C89    2466.0               1
# 2981       Caruana,F  1/2-1/2    2792.0  C89    2743.0               1
# 2982     Abdumalik,Z      1-0    2491.0  C89    2100.0               1
# 2983   Lopusiewicz,P  1/2-1/2    2301.0  C89    2492.0               1
#
#       White Long Castle  Black Short Castle  Black Long Castle  \
# 0                  0                  1                   0
# 1                  0                  1                   0
# 2                  0                  1                   0
# 3                  0                  1                   0
# 4                  0                  1                   0
# ...              ...                ...                 ...
# 2979               0                  1                   0
# 2980               0                  1                   0
# 2981               0                  1                   0
# 2982               0                  1                   0
# 2983               0                  1                   0
#
#       Opposite side castling           Evals  WhiteWon  BlackWon  Moves  \
# 0                  0          [38, 54, 25...         0         1     85
# 1                  0          [35, 43, 27...         1         0     36
# 2                  0          [30, 54, 55...         1         0     17
# 3                  0          [37, 48, 46...         0         1     19
# 4                  0          [26, 50, 52...         0         1     20
# ...              ...                     ...       ...       ...    ...
# 2979               0          [26, 28, 27...         0         0     55
# 2980               0          [25, 50, 41...         1         0     51
# 2981               0          [24, 37, 35...         0         0     37
# 2982               0          [34, 54, 45...         1         0     42
# 2983               0          [35, 50, 25...         0         0     88
#
#       WhiteFinalPiecesCount  BlackFinalPiecesCount  FinalPiecesCount  \
# 0                  1                      3                      4
# 1                  7                      5                     12
# 2                 12                     10                     22
# 3                 11                     10                     21
# 4                 11                     11                     22
# ...              ...                    ...                    ...
# 2979               2                      1                      3
# 2980               8                      5                     13
# 2981               4                      4                      8
# 2982               6                      5                     11
# 2983               0                      0                      0
#
#       QueenTrade
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0
# ...          ...
# 2979           1
# 2980           0
# 2981           1
# 2982           1
# 2983           1
#
# [2984 rows x 23 columns]

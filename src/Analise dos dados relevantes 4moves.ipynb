# %%
import pandas as pd

pd.set_option('display.max_columns', None)
#pd.reset_option('display.max_rows')
pd.set_option('display.max_rows', 20)  # ao invés de none pode por INT do limite
pd.set_option('display.max_colwidth', 15)

# %%
df = pd.read_csv('../data/df_subvar_9-10.csv')

# %%
df = df.loc[(df['WhiteElo'] >= 2500) | (df['WhiteElo'].isna())]
df = df.loc[(df['BlackElo'] >= 2500) | (df['BlackElo'].isna())]

# %% [markdown]
# # Variações totais
# -	9. d3 dxe4 10. dxe4 Qxd1
# -	9. d4 Nxe4 10. dxe5 Be6
# -	9. d4 exd4 10. e5 Ne4
# -	9. exd5 Nxd5 10. Nxe5 Nxe5
# -	9. exd5 Nxd5 10. d4 exd4
# -	9. exd5 e4 10. Ng5 Bg4
# -	9. exd5 e4 10. dxc6 exf3

# %%
#Escolhe variações que foram jogadas mais de dez vezes
df = df.loc[
    (df['SubVariation'] == '9. d3 dxe4 10. dxe4 Qxd1') |
    (df['SubVariation'] == '9. d4 Nxe4 10. dxe5 Be6') |
    (df['SubVariation'] == '9. d4 exd4 10. e5 Ne4') |
    (df['SubVariation'] == '9. exd5 Nxd5 10. Nxe5 Nxe5') |
    (df['SubVariation'] == '9. exd5 Nxd5 10. d4 exd4') |
    (df['SubVariation'] == '9. exd5 e4 10. Ng5 Bg4') |
    (df['SubVariation'] == '9. exd5 e4 10. dxc6 exf3')
]

# %%
df = df.sort_values('SubVariation')
df
# Out:
#            id           Event            Site  Date           White  \
# 688    446748       Meudon op          Meudon  1991       Colin, A.
# 759    493237  BL9192 (Women)         Germany  1992  Braennstroe...
# 35      21627   Dubrovnik olm       Dubrovnik  1950  Kupferstich...
# 341    219136      Alkmaar op         Alkmaar  1984  Van der Wak...
# 1083   717276       Slovan op      Bratislava  1996     Kozak, Petr
# ...       ...             ...             ...   ...             ...
# 29      17354  Trencianske...  Trencianske...  1949  O'Kelly de ...
# 96      63572    Sao Paulo zt       Sao Paulo  1960     Recalde, E.
# 27      16041  Saltsjobade...    Saltsjobaden  1948  Boleslavsky...
# 176    116776          BCF-ch      Sunderland  1966       Coast, P.
# 1613  1056216  20th North ...        Esbjerg   2005  Kristensen,...
#
#                Black   Result  BlackElo  ECO  WhiteElo  WhiteWon  BlackWon  \
# ...

# %%
df['SubVariation'].unique()
# Out:
# array(['9. d3 dxe4 10. dxe4 Qxd1', '9. d4 Nxe4 10. dxe5 Be6',
#        '9. d4 exd4 10. e5 Ne4', '9. exd5 Nxd5 10. Nxe5 Nxe5',
#        '9. exd5 Nxd5 10. d4 exd4', '9. exd5 e4 10. Ng5 Bg4',
#        '9. exd5 e4 10. dxc6 exf3'], dtype=object)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

plt.figure(figsize=(30, 20))
# define the mask to set the values in the upper triangle to True
mask = np.triu(np.ones_like(df.corr(), dtype=np.bool))
heatmap = sns.heatmap(df.corr(), mask=mask, vmin=-1, vmax=1, annot=True, cmap='BrBG')
#heatmap.set_title('asd', fontdict={'fontsize':32}, pad=16);
# Out:
# C:\Users\edupo\AppData\Local\Temp\ipykernel_17336\2469112444.py:7: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask = np.triu(np.ones_like(df.corr(), dtype=np.bool))

# %%
# Plot the orbital period with horizontal boxes
fig, ax = plt.subplots(1,1, figsize=(10,20))

sns.boxplot(y="DifProjection", data=df,
            whis=[0, 100], width=0.6, palette="vlag", ax=ax)
# Out:
# <AxesSubplot:ylabel='DifProjection'>

# %%
# Plot the orbital period with horizontal boxes
sns.boxplot(x="Result", y="Moves", data=df,
            whis=[0, 100], width=.6, palette="vlag")
# Out:
# <AxesSubplot:xlabel='Result', ylabel='Moves'>

# %%
fig, ax = plt.subplots(1,1, figsize=(20,15))
# Plot the orbital period with horizontal boxes
sns.boxplot(x="SubVariation", y="DifProjection", data=df,
            whis=1.5, width=.6, palette="vlag", ax=ax, showcaps=False, showfliers=False)

ax.yaxis.grid(True) # Hide the horizontal gridlines
ax.xaxis.grid(True) # Show the vertical gridlines

# %%
df_resultcount = df.groupby(['SubVariation','Date'])['Result'].size().reset_index(name='GamesCount')
df_resultcount.sort_values(by='Date')
# Out:
#        SubVariation  Date  GamesCount
# 44   9. exd5 Nxd...  1918           1
# 129  9. exd5 Nxd...  1918           1
# 45   9. exd5 Nxd...  1921           2
# 46   9. exd5 Nxd...  1926           1
# 47   9. exd5 Nxd...  1927           1
# ..              ...   ...         ...
# 42   9. d4 exd4 ...  2019           1
# 126  9. exd5 Nxd...  2019          29
# 127  9. exd5 Nxd...  2020           6
# 128  9. exd5 Nxd...  2021          11
# 43   9. d4 exd4 ...  2021           1
#
# [185 rows x 3 columns]

# %%
df_resultcount = df_resultcount.set_index(['SubVariation','Date'])
df_resultcount['GamesCountMA'] = df_resultcount['GamesCount'].rolling(7, center=True).mean()
df_resultcount = df_resultcount.reset_index()

# %%
#fig, ax = plt.subplots(1,1, figsize=(20,15))
sns.relplot(
    data=df_resultcount,
    x="Date", y="GamesCountMA",
    hue="SubVariation",
    kind="line",
    height=16, aspect=1.75, palette='Set1', lw=3.5,
)

# %%
df_resultcount = df_resultcount.sort_values(by='SubVariation')
df_resultcount['total'] = df_resultcount['GamesCountMA']
df_resultcount['SubVariation'].unique().tolist()
# Out:
# ['9. d3 dxe4 10. dxe4 Qxd1',
#  '9. d4 Nxe4 10. dxe5 Be6',
#  '9. d4 exd4 10. e5 Ne4',
#  '9. exd5 Nxd5 10. Nxe5 Nxe5',
#  '9. exd5 Nxd5 10. d4 exd4',
#  '9. exd5 e4 10. Ng5 Bg4',
#  '9. exd5 e4 10. dxc6 exf3']

# %%
df_resultcount = df_resultcount.sort_values(by='Date')
df_resultcount_var3 = df_resultcount.loc[df_resultcount['SubVariation'] ==  '9. d3 dxe4 10. dxe4 Qxd1']
df_resultcount_var6 = df_resultcount.loc[df_resultcount['SubVariation'] ==  '9. d4 Nxe4 10. dxe5 Be6']
df_resultcount_var9 = df_resultcount.loc[df_resultcount['SubVariation'] ==  '9. d4 exd4 10. e5 Ne4']
df_resultcount_var10 = df_resultcount.loc[df_resultcount['SubVariation'] ==  '9. exd5 Nxd5 10. Nxe5 Nxe5']
df_resultcount_var11 = df_resultcount.loc[df_resultcount['SubVariation'] ==  '9. exd5 Nxd5 10. d4 exd4']
df_resultcount_var12 = df_resultcount.loc[df_resultcount['SubVariation'] ==  '9. exd5 e4 10. Ng5 Bg4']
df_resultcount_var13 = df_resultcount.loc[df_resultcount['SubVariation'] ==  '9. exd5 e4 10. dxc6 exf3']

# %%
def get_total_games(row):
   
    global count_anterior

    row['total'] = row['GamesCount'] + count_anterior
    count_anterior += row['GamesCount']
   
    return row

count_anterior = 0
df_resultcount_var3 = df_resultcount_var3.apply(lambda row: get_total_games(row), axis=1)
count_anterior = 0
df_resultcount_var6 = df_resultcount_var6.apply(lambda row: get_total_games(row), axis=1)
count_anterior = 0
df_resultcount_var9 = df_resultcount_var9.apply(lambda row: get_total_games(row), axis=1)
count_anterior = 0
df_resultcount_var10 = df_resultcount_var10.apply(lambda row: get_total_games(row), axis=1)
count_anterior = 0
df_resultcount_var11 = df_resultcount_var11.apply(lambda row: get_total_games(row), axis=1)
count_anterior = 0
df_resultcount_var12 = df_resultcount_var12.apply(lambda row: get_total_games(row), axis=1)
count_anterior = 0
df_resultcount_var13 = df_resultcount_var13.apply(lambda row: get_total_games(row), axis=1)

# %%
fig, ax = plt.subplots(1, figsize=(30,10))
ax.fill_between(df_resultcount_var3['Date'], df_resultcount_var3['GamesCountMA'], facecolor='C1', alpha=0.4, label='9. d3 dxe4 10. dxe4 Qxd1')
ax.fill_between(df_resultcount_var6['Date'], df_resultcount_var6['GamesCountMA'], facecolor='C2', alpha=0.4, label='9. d4 Nxe4 10. dxe5 Be6')
ax.fill_between(df_resultcount_var9['Date'], df_resultcount_var9['GamesCountMA'], facecolor='C3', alpha=0.4, label='9. d4 exd4 10. e5 Ne4')
ax.fill_between(df_resultcount_var10['Date'], df_resultcount_var10['GamesCountMA'], facecolor='C4', alpha=0.4, label='9. exd5 Nxd5 10. Nxe5 Nxe5')
ax.fill_between(df_resultcount_var11['Date'], df_resultcount_var11['GamesCountMA'], facecolor='C5', alpha=0.4, label='9. exd5 Nxd5 10. d4 exd4')
ax.fill_between(df_resultcount_var12['Date'], df_resultcount_var12['GamesCountMA'], facecolor='C6', alpha=0.4, label='9. exd5 e4 10. Ng5 Bg4')
ax.fill_between(df_resultcount_var13['Date'], df_resultcount_var13['GamesCountMA'], facecolor='C0', alpha=0.4, label='9. exd5 e4 10. dxc6 exf3')
ax.legend(loc='upper left')

# %%
fig, ax = plt.subplots(1, figsize=(30,10))
ax.fill_between(df_resultcount_var3['Date'], df_resultcount_var3['total'], facecolor='C2', alpha=0.1, label='9. d3 dxe4 10. dxe4 Qxd1')
ax.fill_between(df_resultcount_var6['Date'], df_resultcount_var6['total'], facecolor='C5', alpha=0.1, label='9. d4 Nxe4 10. dxe5 Be6')
ax.fill_between(df_resultcount_var9['Date'], df_resultcount_var9['total'], facecolor='C8', alpha=0.1, label='9. d4 exd4 10. e5 Ne4')
ax.fill_between(df_resultcount_var10['Date'], df_resultcount_var10['total'], facecolor='C9', alpha=0.1, label='9. exd5 Nxd5 10. Nxe5 Nxe5')
ax.fill_between(df_resultcount_var11['Date'], df_resultcount_var11['total'], facecolor='C10', alpha=0.1, label='9. exd5 Nxd5 10. d4 exd4')
ax.fill_between(df_resultcount_var12['Date'], df_resultcount_var12['total'], facecolor='C11', alpha=0.1, label='9. exd5 e4 10. Ng5 Bg4')
ax.fill_between(df_resultcount_var13['Date'], df_resultcount_var13['total'], facecolor='C12', alpha=0.1, label='9. exd5 e4 10. dxc6 exf3')
ax.legend(loc='upper left')

# %%
fig, ax = plt.subplots(1, figsize=(15,20))
ax.plot(df_resultcount_var3['Date'], df_resultcount_var3['total'], alpha=1, label='9. d3 dxe4 10. dxe4 Qxd1')
ax.plot(df_resultcount_var6['Date'], df_resultcount_var6['total'], alpha=1, label='9. d4 Nxe4 10. dxe5 Be6')
ax.plot(df_resultcount_var9['Date'], df_resultcount_var9['total'], alpha=1, label='9. d4 exd4 10. e5 Ne4')
#ax.plot(df_resultcount_var10['Date'], df_resultcount_var10['total'], alpha=1, label='9. exd5 Nxd5 10. Nxe5 Nxe5')
ax.plot(df_resultcount_var11['Date'], df_resultcount_var11['total'], alpha=1, label='9. exd5 Nxd5 10. d4 exd4')
ax.plot(df_resultcount_var12['Date'], df_resultcount_var12['total'], alpha=1, label='9. exd5 e4 10. Ng5 Bg4')
ax.plot(df_resultcount_var13['Date'], df_resultcount_var13['total'], alpha=1, label='9. exd5 e4 10. dxc6 exf3')
ax.legend(loc='upper left')

# %%
list_df_variations = [df_resultcount_var3,df_resultcount_var6,df_resultcount_var9,df_resultcount_var10,df_resultcount_var11,df_resultcount_var12,df_resultcount_var13]
contador = 0
variations_info = []
for variation in list_df_variations:
    contador += 1
    info = {}
    info['id'] = contador
    info['Variation'] = variation['SubVariation'].iloc[0] # variation

    gamescount = variation['GamesCount'].tolist() #lista da qntd de jogos por ano
    max_year_qntd = max(gamescount) #qntd de jogos no ano q mais teve
    max_year_qntd_index = gamescount.index(max_year_qntd) #indice da var com qntd de jogos no ano q mais teve
    info['PicoQntdJogos'] = max_year_qntd #o pico de jogos jogados da variation

    pico_ano = variation.loc[variation['GamesCount'] == max_year_qntd]['Date'].iloc[0] # descobre qual o ano que ocorreu o pico
    info['PicoAno'] = pico_ano

    info['Total'] = variation['total'].iloc[-1] #total de jogos da variation

    print(info)

    variations_info.append(info)
# Out:
# {'id': 1, 'Variation': '9. d3 dxe4 10. dxe4 Qxd1', 'PicoQntdJogos': 2, 'PicoAno': 1997, 'Total': 18}
# {'id': 2, 'Variation': '9. d4 Nxe4 10. dxe5 Be6', 'PicoQntdJogos': 4, 'PicoAno': 1950, 'Total': 11}
# {'id': 3, 'Variation': '9. d4 exd4 10. e5 Ne4', 'PicoQntdJogos': 4, 'PicoAno': 2004, 'Total': 31}
# {'id': 4, 'Variation': '9. exd5 Nxd5 10. Nxe5 Nxe5', 'PicoQntdJogos': 55, 'PicoAno': 2008, 'Total': 957}
# {'id': 5, 'Variation': '9. exd5 Nxd5 10. d4 exd4', 'PicoQntdJogos': 4, 'PicoAno': 1994, 'Total': 26}
# {'id': 6, 'Variation': '9. exd5 e4 10. Ng5 Bg4', 'PicoQntdJogos': 2, 'PicoAno': 1991, 'Total': 11}
# {'id': 7, 'Variation': '9. exd5 e4 10. dxc6 exf3', 'PicoQntdJogos': 4, 'PicoAno': 1991, 'Total': 41}
